# %% [markdown]
# # **Data Exploration with Python using Pandas & Numpy Libraries**
#
# # 1. Project Contents:
# * **Project Information**
# * **Description of Data**
# * **Problem Statement**
# * **Project Objectives**
# * **Exploratory Data Analysis**
# * **Observations**
# * **Insights**
# * **Managerial Insights and Recommendations**
#
# # 2. Project Information
# * **Student Name: Jagriti**
# * **Enrollment Number: 55016**
# * **Dataset Source: Imports_Exports_Dataset on Kaggle**
#
# # 3. Description of Data
# * **Data Type: Panel**
# * **Variable Types:**
# # Variables in the Dataset
#
# 1. **Text Variables**:
#    - Transaction_ID
#    - Country
#    - Product
#    - Import_Export
#    - Date
#    - Category
#    - Port
#    - Shipping_Method
#    - Supplier
#    - Customer
#    - Payment_Terms
#
# 2. **Number - Integer Variables**:
#    - Quantity
#    - Customs_Code
#    - Invoice_Number
#
# 3. **Number - Decimal Variables**:
#    - Value
#    - Weight
#
#
# * **Data Variable Category:**
# 1. **Index** - Transaction_ID, Customs_Code, Invoice_Number, Product, Supplier, Customer
# 2. **Categorical - Nominal** - Import_Export, Category, Shipping_Method, Payment_Terms, Country
# 3. **Categorical - Ordinal** - (No specific ordinal variables mentioned)
# 4. **Non-Categorical** - Quantity, Value, Date, Port, Weight
#
# # 4. Problem Statement
# The dataset utilized in this analysis encompasses data on imports and exports. The objective is to explore, clean, and analyze this dataset to identify patterns and insights related to trade statistics. We will employ the Pandas and Numpy libraries for data wrangling, visualization, and analysis to extract actionable insights.
#
# # 5. Project Objectives
#
# 1. Analyze Trade Data: This project centers on analyzing trade data, focusing on imports and exports across various shipping methods, including sea, land, and air.
# 2. Explore Shipping Methods: The goal is to compare the effectiveness and profitability of different shipping methods (sea, air, land) for imports and exports.
# 3. Visualize Data: Various charts, including bar graphs, histograms, and pie charts, will be created to visualize trade data, aiding in the understanding of trends, distributions, and the performance of different categories.
# 4. Identify Key Product Categories: The project aims to identify the most profitable product categories.
# 5. Provide Business Insights: It seeks to deliver actionable insights for businesses, such as optimizing shipping strategies, tracking seasonal trends, and enhancing operational efficiency.
#
# # 6. Exploratory Data Analysis
#
# Pandas is employed to load and manipulate the dataset, facilitating data cleaning, filtering, grouping, and summarizing. Tasks such as creating DataFrames, grouping data, and summarizing values (e.g., calculating total import/export values) are accomplished using Pandas.
#
# Matplotlib for Data Visualization: Matplotlib is utilized for creating static, animated, and interactive visualizations, enabling the plotting of charts to better understand the distribution and relationships between variables.
#
# Various plot types are employed:
#
# Bar Chart: Used to visualize categorical data and compare total values across different categories (e.g., shipping methods, product categories).
# Histogram: To examine the distribution of a numerical variable (e.g., trade values).
# Pie Chart: To illustrate the proportions of categories within the dataset.
# Subplot for Comparative Analysis: Subplots display multiple charts side by side for comparative analysis, allowing insights into different data aspects (e.g., bar chart, histogram, pie chart) within a single figure.
# Tables for Summarizing Data: The report includes tabular outputs summarizing key metrics such as total trade values by shipping method and type (import/export), facilitating quick identification of the most significant components.
# The analysis was primarily divided into Categorical and Non-Categorical variables:
#
# Non-Categorical Variables:
# Measures of Central Tendency: Minimum | Maximum | Mean | Median | Mode | Percentile
# Measures of Dispersion: Range | Standard Deviation | Skewness | Kurtosis | Correlation (Matrix)
# Composite Measure: Coefficient of Variation | Confidence Interval
# Categorical Variables: (Analysis focused on the variable Imports_Exports)
# Count | Frequency | Proportion | Minimum | Maximum | Mode | Rank
#
# # 7. Observations
#
# Dominance of Sea Shipping for Exports: Sea-based exports generate the highest trade value.
# Significant Imports via Land and Sea: Imports via land and sea shipping methods exhibit high trade values, with land-based imports nearly matching sea-based exports.
# Variation in Shipping Method Performance: Air shipping appears to have a smaller impact compared to sea and land methods, likely due to higher costs or lower capacity.
# Product Category Insights: Certain product categories significantly enhance profitability, indicating that focusing on these areas could improve business outcomes.
# Seasonal Trends in Trade Volume: Fluctuations in the data suggest seasonal trends, showing increased trade volumes at specific times.
#
# # 8. Insights
#
# 1. Sea-Based Exports Drive the Highest Trade Value:
#
# **Insight:** Sea shipping dominates export activities, likely due to cost efficiency for bulk goods over long distances.
# **Actionable Step:** Enhance sea freight operations by securing better rates, reducing transit times, and optimizing port handling to maximize profitability.
#
# 2. Land and Sea Imports are Equally Important:
#
# **Insight:** Land and sea methods are crucial for imports, with trade values almost equal, indicating a balanced reliance on these shipping methods.
# **Actionable Step:** Focus on optimizing logistics for both land and sea imports by streamlining inland transportation and customs processes.
#
# 3. Air Shipping Plays a Niche Role:
#
# **Insight:** Although air shipping is less prevalent, it is essential for specific, high-value, time-sensitive goods.
# **Actionable Step:** Utilize air freight for high-margin, perishable, or time-critical products and explore ways to improve cost efficiency.
#
# 4.Focus on High-Performing Product Categories:
#
# **Insight:** Certain product categories likely yield the highest profitability.
# **Actionable Step:** Analyze and prioritize product categories that contribute most to profits to enhance revenue.
# Seasonal Fluctuations Suggest Strategic Planning Opportunities:
#
# **Insight:** Trade volume varies seasonally, suggesting businesses can align operations with peak demand periods.
# **Actionable Step:** Implement data-driven forecasting to anticipate peak seasons and adjust inventory and logistics accordingly.
#
# # 9. Managerial Insights and Recommendations
#
# Cost Efficiency in Shipping Methods:
#
# **Insight:** Sea-based shipping is the most cost-effective and generates the highest trade value.
# Managerial Implication: Prioritize sea freight for bulk exports to reduce costs.
# Recommendation: Establish long-term contracts with sea freight providers to secure favorable rates and evaluate port partnerships to minimize delays.
# Balanced Approach to Imports:
#
# **Insight:** Land and sea methods are equally important for imports.
# **Managerial Implication:** Optimize both shipping routes.
# **Recommendation:** Conduct a cost-benefit analysis on inland transportation for efficient land imports.
# Targeting High-Margin, Time-Sensitive Goods with Air Freight:
#
# **Insight:** Air shipping is less common but essential for high-margin, time-sensitive products.
# **Managerial Implication:** Use air freight strategically for critical deliveries.
# **Recommendation:** Utilize air freight primarily for high-value items and negotiate better terms for frequent shipments.
# Product Portfolio Optimization:
#
# **Insight:** Certain product categories significantly impact profitability.
# **Managerial Implication:** Align production and marketing efforts around high-performing categories.
# **Recommendation:** Increase investment in high-demand products and streamline supply chains to ensure availability.
# Leveraging Seasonal Trends for Better Planning:
#
# **Insight:** Trade volume varies seasonally, indicating the need for dynamic planning.
# **Managerial Implication:** Align operations to efficiently handle peak demand periods.
# **Recommendation:** Implement flexible workforce and inventory management systems to adapt to seasonal demands.
# Technology-Driven Operations:
#
# **Insight:** Advanced technologies can enhance decision-making and improve responsiveness.
# **Managerial Implication:** Embrace data-driven solutions for better supply chain efficiency.
# **Recommendation:** Invest in supply chain management systems and automation for real-time monitoring.
# Risk Mitigation through Diversification:
#
# **Insight:** Over-reliance on specific shipping methods or product categories poses risks.
# **Managerial Implication:** Diversification can reduce risks and provide growth opportunities.
# **Recommendation:** Explore niche markets and diversify the product portfolio to minimize dependency.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# %%
data=pd.read_csv("C:/Users/jagri/OneDrive/Desktop/Imports_Exports_Dataset.csv")
data
# Out:
#                              Transaction_ID           Country    Product  \
# 0      e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1      f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2      eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3      f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4      e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
# ...                                     ...               ...        ...
# 14995  48df15a8-0823-4964-8c16-eddf2756f382  Marshall Islands        not
# 14996  31106617-94a6-4646-a001-5e7bd45abc26           Bermuda        air
# 14997  ee485839-fbde-4ced-af18-d98f5e863081          Tanzania       show
# 14998  5acd54aa-ec8c-4055-be8b-a447861a471c            Tuvalu         TV
# 14999  5cc039d0-a052-41fd-bfbb-c9f60c4565ac   North Macedonia       year
#
#       Import_Export  Quantity    Value        Date     Category  \
# ...

# %%
data.shape
# Out:
# (15000, 16)

# %%
sample=data.sample(n=11, random_state=55016)
sample
# Out:
#                              Transaction_ID  \
# 9154   69c08294-c6e9-4b23-8590-1647b60d4931
# 7576   d7324c71-fa2d-4aa3-983e-93c5f06eca09
# 8708   9e9559db-c977-48df-a53e-6619a89b3e94
# 2292   7b9ba35c-8e29-4c03-8e75-3f5774b183dc
# 5275   710821bd-4a20-4ad7-b8f7-c9ae57dc56f2
# 2194   da09fb60-2d27-4d76-86e0-c466b68c76f8
# 12999  2456ae36-b900-4a48-91b2-c980dd050cb6
# 853    dd9539fc-f7cd-4b75-9d26-3e763d3703f8
# 13614  ec7b7771-03aa-4963-a709-e1b2e44afa15
# 1389   c3e6652c-0f52-40a2-915c-3e9276181f28
# 2285   41d1c954-107a-44af-9c72-4d49e375d8af
#
#                                                  Country      Product  \
# 9154                               Saint Kitts and Nevis      soldier
# 7576                                             Grenada        style
# 8708                                              Poland        trial
# 2292                                           Sri Lanka       matter
# 5275                                    Pitcairn Islands       decide
# ...

# %%
sample.shape
# Out:
# (11, 16)

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 9154 to 2285
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   11 non-null     object
#  1   Country          11 non-null     object
#  2   Product          11 non-null     object
#  3   Import_Export    11 non-null     object
#  4   Quantity         11 non-null     int64
#  5   Value            11 non-null     float64
#  6   Date             11 non-null     object
#  7   Category         11 non-null     object
#  8   Port             11 non-null     object
#  9   Customs_Code     11 non-null     int64
#  10  Weight           11 non-null     float64
#  11  Shipping_Method  11 non-null     object
#  12  Supplier         11 non-null     object
#  13  Customer         11 non-null     object
#  14  Invoice_Number   11 non-null     int64
#  15  Payment_Terms    11 non-null     object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
sample.head(3)
# Out:
#                             Transaction_ID                Country  Product  \
# 9154  69c08294-c6e9-4b23-8590-1647b60d4931  Saint Kitts and Nevis  soldier
# 7576  d7324c71-fa2d-4aa3-983e-93c5f06eca09                Grenada    style
# 8708  9e9559db-c977-48df-a53e-6619a89b3e94                 Poland    trial
#
#      Import_Export  Quantity    Value        Date     Category          Port  \
# 9154        Export       688  5354.27  11-04-2022     Clothing  Rubioborough
# 7576        Export      9131  7652.64  21-11-2022     Clothing    Jamesshire
# 8708        Export      2181  4987.60  09-08-2022  Electronics  Williamville
#
#       Customs_Code   Weight Shipping_Method                        Supplier  \
# 9154        673350  1171.68             Air                       Pratt Ltd
# 7576        356119  1992.87            Land                   Rodriguez LLC
# 8708        366694  4921.83             Sea  Johnston, Williams and Elliott
#
# ...

# %%
#listinng variables
sample.columns
# Out:
# Index(['Transaction_ID', 'Country', 'Product', 'Import_Export', 'Quantity',
#        'Value', 'Date', 'Category', 'Port', 'Customs_Code', 'Weight',
#        'Shipping_Method', 'Supplier', 'Customer', 'Invoice_Number',
#        'Payment_Terms'],
#       dtype='object')

# %%
#Subset of Categorical Variables
categorical_nominal_variables = sample[['Country', 'Product', 'Import_Export', 'Category', 'Port', 'Customs_Code', 'Shipping_Method', 
                                      'Supplier', 'Customer', 'Invoice_Number', 'Payment_Terms']]
categorical_nominal_variables
# Out:
#                                                  Country      Product  \
# 9154                               Saint Kitts and Nevis      soldier
# 7576                                             Grenada        style
# 8708                                              Poland        trial
# 2292                                           Sri Lanka       matter
# 5275                                    Pitcairn Islands       decide
# 2194                                            Malaysia       strong
# 12999                                              Congo  information
# 853                                                India          war
# 13614                                       Saudi Arabia        stage
# 1389                                         Philippines           at
# 2285   British Indian Ocean Territory (Chagos Archipe...       record
#
#       Import_Export     Category            Port  Customs_Code  \
# ...

# %%
#Subset of Non-Categorical Variables
non_categorical_variables = sample[['Quantity', 'Value', 'Weight']]
non_categorical_variables
# Out:
#        Quantity    Value   Weight
# 9154        688  5354.27  1171.68
# 7576       9131  7652.64  1992.87
# 8708       2181  4987.60  4921.83
# 2292       7108  7895.51  2610.26
# 5275       1139  4020.71  2066.48
# 2194       2291  3869.72  2593.73
# 12999      2569  6798.29  2494.18
# 853        9286  1098.28  2653.16
# 13614      5997  3371.19   579.95
# 1389        333  7317.25  2154.22
# 2285       4569  8579.31  4750.52

# %%
# B2. Identify & List the following Variables:
# 1. Index Variables
index_variable = sample['Transaction_ID']

# 2. Non-Categorical Variables
non_categorical_variables = sample[['Quantity', 'Value', 'Weight']]

# 3. Categorical Variables - Nominal Type
categorical_nominal_variables = sample[['Country', 'Product', 'Import_Export', 'Category', 'Port', 'Customs_Code', 'Shipping_Method', 
                                      'Supplier', 'Customer', 'Invoice_Number', 'Payment_Terms']]

# 4. Categorical Variables - Ordinal Type
categorical_ordinal_variables = sample['Date']

combined_table = pd.concat([index_variable, non_categorical_variables, categorical_nominal_variables, categorical_ordinal_variables], axis=1)
print(tabulate(combined_table, headers='keys', tablefmt='grid'))
# Out:
# +-------+--------------------------------------+------------+---------+----------+-----------------------------------------------------+-------------+-----------------+-------------+----------------+----------------+-------------------+--------------------------------+-------------------+------------------+------------------+------------+
# |       | Transaction_ID                       |   Quantity |   Value |   Weight | Country                                             | Product     | Import_Export   | Category    | Port           |   Customs_Code | Shipping_Method   | Supplier                       | Customer          |   Invoice_Number | Payment_Terms    | Date       |
# ...

# %% [markdown]
# # Analysis of Non-categorical Variables

# %%
nonCat = sample[['Quantity', 'Value', 'Weight']]
nonCat.describe()
# Out:
#           Quantity        Value       Weight
# count    11.000000    11.000000    11.000000
# mean   4117.454545  5540.433636  2544.443636
# std    3301.021005  2320.804209  1302.632639
# min     333.000000  1098.280000   579.950000
# 25%    1660.000000  3945.215000  2029.675000
# 50%    2569.000000  5354.270000  2494.180000
# 75%    6552.500000  7484.945000  2631.710000
# max    9286.000000  8579.310000  4921.830000

# %%
plt.figure(figsize=(15, 10))

for i, column in enumerate(nonCat, 1):
    plt.subplot(2, 3, i)  # Create a grid for the subplots (2 rows, 3 columns)
    nonCat.boxplot(column=column, showmeans=True, meanline=True, meanprops={"linestyle": "--", "color": "red"})
    plt.title(f"Box Plot of {column}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Anomalies :
#
# #### Outliers:
#
# Outliers are data points that significantly deviate from the rest of the data. They are often represented by individual points or small groups of points outside the whiskers of the box plot.
#
# ##### Based on the provided box plots, it appears that:
#
# -Quantity: There are no apparent outliers since the whiskers extend to include all data points.
#
# -Value: Similar to Quantity, there are no outliers. The whiskers include all data points.
#
# -Weight: No outliers are seen here either, as the whiskers include all the values.
#
# #### Skewness:
#
# Skewness refers to the asymmetry of the distribution. A distribution is skewed to the right (positively skewed) if the tail on the right side is longer, and skewed to the left (negatively skewed) if the tail on the left side is longer.
#
# *Quantity: The median (green line) is slightly above the center of the box, which may indicate a small skew to the left (negative skew). This suggests that the majority of values are clustered slightly on the higher side of the distribution.
# Value: The median is somewhat below the center of the box, indicating a slight positive skew. This suggests more data points fall below the median, with a long tail extending toward higher values.
#
# Weight: The median is also slightly below the center of the box, suggesting a positive skew as well. A higher concentration of lower-weight values with a longer tail towards higher weights is possible.*
#
# #### Additional Observations:
#
# -Quantity The spread (IQR) of data is relatively large, indicating a good amount of variability in the data. The range is from approximately 1000 to 8000 units, with most values falling between 4000 and 6000
#
# -Value The range of values goes from close to 0 to just over 8000, and the majority of values are between 4000 and 6000. The slight positive skew indicates that there are some higher-value transactions pulling the distribution rightward
#
# -Overall, the box plots provide a clear visual representation of the distribution of these variables, allowing for easy identification of outliers and potential skewness.

# %%
correlation_matrix = nonCat.corr()

# Plotting a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Non-Categorical Variables')
plt.show()

# %% [markdown]
# #### Positively correlated variables:
#
# Value and Quantity: The correlation coefficient between these two variables is 0.021, indicating a strong positive correlation. This means that as quantity increases, value also tends to increase.
#
# #### Negatively correlated variables:
#
# Weight and Value: The correlation coefficient between these two variables is -0.56. This indicates a moderate negative relationship between the two variables, meaning that as the weight increases, the value tends to decrease, and vice versa

# %% [markdown]
# ### Establishing Causality:
#
# #### Positively Correlated Variables:
#
# **Value** and **Quantity**:
# There is a plausible relationship between value and quantity, where an increase in the number of goods traded typically leads to an increase in the overall value of the transaction. However, other factors such as market demand, product pricing, and cost efficiencies could also influence the trade value.
#
# #### Negatively Correlated Variables:
#
# **Weight** and **Value**:
# Heavier shipments tend to have a lower overall trade value. This suggests that higher-weight goods are often associated with lower per-unit prices. However, this relationship can also be influenced by the type of product being shipped, its market, and transportation costs.
#
# ---
#
# ### *1. Focus on High-Quantity Goods to Increase Value*
#
# **Insight:**
# There is a positive correlation between **Quantity** and **Value**, suggesting that increasing the number of goods being traded leads to higher transaction values. The correlation indicates that higher quantities drive greater overall value, though other factors like pricing and demand will also play a role.
#
# **Recommendation:**
# To increase trade value, focus on selling larger quantities of goods, leveraging bulk pricing, and improving operational efficiencies. For high-demand products, ensure adequate supply to meet volume requirements and boost value through scaling operations.
#
# ---
#
# ### *2. Managing the Weight vs. Value Trade-Off*
#
# **Insight:**
# There is a negative correlation between **Weight** and **Value**, meaning heavier shipments tend to have lower transaction values. This could suggest that heavy goods, like raw materials, are often lower in price per unit compared to lighter, more valuable goods.
#
# **Recommendation:**
# Focus on optimizing shipment strategies for heavier goods to reduce the cost-to-value ratio. For high-weight, low-value goods, explore bulk transport solutions (e.g., sea freight) to minimize costs. Additionally, consider balancing shipments with higher-value, lower-weight products to increase the overall value.
#
# ---
#
# ### *3. Explore Lighter, High-Value Product Offerings*
#
# **Insight:**
# Given the inverse relationship between **Weight** and **Value**, lighter products tend to have a higher value. This could indicate an opportunity to focus on goods that have a better weight-to-value ratio, such as electronics or luxury items.
#
# **Recommendation:**
# Shift your product mix to focus on lighter, higher-value goods that can be transported more efficiently, thus increasing profitability. Consider expanding into markets for high-tech goods or luxury items that have a favorable weight-to-value ratio, reducing transportation costs while maintaining high value.
#
# ---
#
# ### *4. Optimizing Logistics for Heavy, Low-Value Goods*
#
# **Insight:**
# The strong negative correlation between **Weight** and **Value** suggests that heavier goods are typically lower in price. This makes optimizing logistics crucial for maintaining profitability when dealing with bulk shipments of low-value goods.
#
# **Recommendation:**
# For heavy, low-value goods, emphasize optimizing logistics by choosing cost-effective shipping methods like sea or rail transport. Look for ways to consolidate shipments to reduce costs, and explore partnerships with shipping providers to secure better rates for bulk transport.
#
# ---
#
# ### *5. Customizing Product Strategy for Value Maximization*
#
# **Insight:**
# Different product categories may have distinct weight-to-value relationships, and customers will prioritize value over quantity or weight depending on the type of product.
#
# **Recommendation:**
# Segment your market based on the weight-to-value preferences of your customers. Offer tailored product options, such as high-value, lightweight goods for premium customers, and bulk, low-cost products for customers focused on quantity. This segmentation can help you optimize your product offerings and better meet market demand.
#
# ---
#
# ### *6. Comprehensive Design of Product Portfolio for Profit Maximization*
#
# **Insight:**
# The overall relationship between **Quantity**, **Value**, and **Weight** indicates that larger shipments often increase the total value, but too much weight negatively impacts the trade value. Therefore, balancing these factors is key to maximizing profitability.
#
# **Recommendation:**
# For optimal results, design a product portfolio that balances higher quantities of goods with lighter, higher-value items. By focusing on reducing weight while maintaining quantity and value, you can optimize your logistics and reduce transportation costs, ultimately improving margins.
#
# ---
#
# ### *7. Data-Driven Strategies for Customer Segmentation*
#
# **Insight:**
# Different customer segments may prioritize either value, quantity, or weight in their purchasing decisions, depending on their business needs.
#
# **Recommendation:**
# Use this correlation data to segment your customer base and develop targeted marketing strategies:
# - **Value-seeking customers**: Emphasize high-value, lightweight products for customers who prioritize value over bulk.
# - **Quantity-focused customers**: Offer bulk purchasing options for customers interested in maximizing quantity while keeping costs low.
# - **Heavy-product customers**: Provide optimized logistics solutions for those purchasing high-weight, low-value goods, focusing on reducing their overall shipping costs.
#
# ---
#
# By understanding these causal relationships between **Value**, **Quantity**, and **Weight**, businesses can optimize their product strategies, logistics, and customer segmentation to maximize trade value and profitability.
# nclude messaging around balancing fuel consumption.

# %%
# Sort nonCat DataFrame by the specified column for each plot
# 1. Weight (Weight) Reduction for Value (Value)
sorted_df = sample.sort_values(by='Weight')  # Sort by weight
weight = sorted_df['Weight']
value = sorted_df['Value']

plt.figure(figsize=(10, 6))
plt.scatter(weight, value, color='red')
plt.plot(weight, value, color='red')  # Optional trendline
plt.title('Weight vs. Value (Ascending Weight)')
plt.xlabel('Weight (Weight)')
plt.ylabel('Value (Value)')
plt.grid(True)
plt.show()

# 2. Quantity vs. Value Trade-Off
sorted_df = sample.sort_values(by='Quantity')  # Sort by quantity
quantity = sorted_df['Quantity']
value = sorted_df['Value']

plt.figure(figsize=(10, 6))
plt.scatter(quantity, value, color='blue')
plt.plot(quantity, value, color='blue')  # Optional trendline
plt.title('Quantity vs. Value (Ascending Quantity)')
plt.xlabel('Quantity')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# 3. Quantity and Weight Increase
sorted_df = sample.sort_values(by='Quantity')  # Sort by Quantity
quantity = sorted_df['Quantity']
weight = sorted_df['Weight']

plt.figure(figsize=(10, 6))
plt.scatter(quantity, weight, color='green')
plt.plot(quantity, weight, color='green')  # Optional trendline
plt.title('Quantity vs. Weight (Ascending Quantity)')
plt.xlabel('Quantity')
plt.ylabel('Weight')
plt.grid(True)
plt.show()

# 4. Value vs. Quantity
sorted_df = sample.sort_values(by='Value')  # Sort by Value
value = sorted_df['Value']
quantity = sorted_df['Quantity']

plt.figure(figsize=(10, 6))
plt.scatter(value, quantity, color='orange')
plt.plot(value, quantity, color='orange')  # Optional trendline
plt.title('Value vs. Quantity (Ascending Value)')
plt.xlabel('Value')
plt.ylabel('Quantity')
plt.grid(True)
plt.show()

# 5. Weight vs. Value
sorted_df = sample.sort_values(by='Weight')

weight = sorted_df['Weight']
value = sorted_df['Value']

plt.figure(figsize=(10, 6))
plt.scatter(weight, value, color='purple')  # Plot sorted data points
plt.plot(weight, value, color='purple')  # Plot trendline (optional)
plt.title('Weight vs. Value (Ascending Order)')
plt.xlabel('Weight')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Managerial Insights and Recommendations
#
# **Based on the above graphs, some key insights and recommendations are:**
#
# ### Weight vs. Value
# * **Negative Correlation:** There is a negative correlation between weight and the value of shipments. Heavier shipments tend to have lower values.
# * **Recommendation:** Focus on optimizing shipments by balancing high-value, lightweight items with heavier goods to increase the overall shipment value. For low-value, high-weight goods, explore ways to reduce transportation costs by negotiating bulk shipping rates or using more cost-effective shipping methods.
#
# ### Quantity vs. Value
# * **Positive Correlation:** There's a positive correlation between quantity and value. Higher quantities of goods generally result in higher transaction values.
# * **Recommendation:** Manufacturers and businesses should prioritize selling larger quantities of goods to boost revenue. Consider offering bulk discounts or promotions to encourage larger purchases and increase the overall value of transactions.
#
# ### Quantity vs. Weight
# * **Positive Correlation:** A positive correlation exists between quantity and weight. Higher quantities of goods tend to increase the overall shipment weight.
# * **Recommendation:** Ensure that transportation and logistics are optimized to handle large shipments efficiently. Invest in better packaging and transportation techniques to minimize costs related to heavy shipments while maximizing the number of goods being transported.
#
# ### Value vs. Quantity
# * **Positive Correlation:** There is a positive correlation between value and quantity. As the quantity of goods increases, so does the total value.
# * **Recommendation:** Focus on high-volume product sales to increase overall revenue. Offering scalable pricing models for bulk buyers can help businesses capitalize on this relationship.
#
# ### Weight vs. Value (Revisited)
# * **Negative Correlation:** The negative correlation between weight and value suggests that lighter goods tend to have a higher value.
# * **Recommendation:** Companies should explore opportunities to increase the shipment of lighter, high-value goods. This can improve the profit margin on shipments while reducing costs related to transporting heavy, low-value goods.
#
# ---
#
# ## Overall Recommendations:
#
# 1. **Maximize Shipment Value:** Prioritize shipping higher quantities of goods, especially when they are lightweight but high-value, to increase revenue.
# 2. **Reduce Transportation Costs for Heavier Shipments:** Explore bulk shipping discounts and optimize logistics for transporting heavy, lower-value goods.
# 3. **Incentivize Bulk Purchases:** Offer promotions or discounts for customers buying in bulk to increase the overall value of each transaction.
# 4. **Balance Product Portfolio:** Businesses should focus on a mix of lightweight, high-value goods alongside heavier, lower-value commodities to balance transportation costs and revenue generation.
# 5. **Optimize Packaging and Logistics:** Invest in innovative packaging solutions to reduce the weight of goods without compromising on quality, ensuring efficient transport and maximizing profits.
# 6. **Target Market Segmentation:** Use data-driven insights to segment the market and offer tailored solutions based on customer preferences for lightweight, high-value goods or bulk, low-cost shipments.
#
# **By implementing these recommendations, businesses can increase shipment value, optimize logistics, and improve overall profitability in their operations.**

# %%
# Measures of Dispersion {Range | Standard Deviation | Skewness | Kurtosis | Correlation}

# Step 1: Range for Quantity and Value
range_quantity = sample['Quantity'].max() - sample['Quantity'].min()
range_value = sample['Value'].max() - sample['Value'].min()

# Step 2: Standard Deviation for Quantity and Value
std_quantity = sample['Quantity'].std()
std_value = sample['Value'].std()

# Step 3: Skewness for Quantity and Value
skew_quantity = sample['Quantity'].skew()
skew_value = sample['Value'].skew()

# Step 4: Kurtosis for Quantity and Value
kurt_quantity = sample['Quantity'].kurtosis()
kurt_value = sample['Value'].kurtosis()

# Step 5: Correlation Matrix for Quantity, Value, and Weight
correlation_matrix = sample[['Quantity', 'Value', 'Weight']].corr()

# Display all the results in a human-readable format
print(f"Range of Quantity: {range_quantity}")
print(f"Range of Value: {range_value}\n")

print(f"Standard Deviation of Quantity: {std_quantity}")
print(f"Standard Deviation of Value: {std_value}\n")

print(f"Skewness of Quantity: {skew_quantity}")
print(f"Skewness of Value: {skew_value}\n")

print(f"Kurtosis of Quantity: {kurt_quantity}")
print(f"Kurtosis of Value: {kurt_value}\n")

print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Range of Quantity: 8953
# Range of Value: 7481.03
#
# Standard Deviation of Quantity: 3301.0210045874096
# Standard Deviation of Value: 2320.8042091881543
#
# Skewness of Quantity: 0.542103533480328
# Skewness of Value: -0.4699487082998348
#
# Kurtosis of Quantity: -1.24692488106722
# Kurtosis of Value: -0.5445336534516225
#
# Correlation Matrix:
#           Quantity     Value    Weight
# Quantity  1.000000 -0.096815 -0.039779
# Value    -0.096815  1.000000  0.274587
# Weight   -0.039779  0.274587  1.000000

# %%
# Composite Measure {Coefficient of Variation | Confidence Interval}

import scipy.stats as stats

sample = np.array([10, 20, 30, 40, 50])

# Mean and Standard Deviation
mean = np.mean(sample)  # Mean of the data
std_dev = np.std(sample)  # Standard deviation of the data

# Coefficient of Variation (CV)
# CV is a measure of relative variability (standard deviation divided by mean)
cv = (std_dev / mean) * 100  # Expressed as a percentage

# Confidence Interval (CI)
# CI provides a range in which the true mean is likely to fall
confidence_level = 0.95  # 95% confidence level
n = len(data)  # Sample size
std_error = std_dev / np.sqrt(n)  # Standard error of the mean

# Z-score for 95% confidence level (from standard normal distribution)
z_value = stats.norm.ppf(1 - (1 - confidence_level) / 2)

# Confidence interval bounds
ci_lower = mean - z_value * std_error
ci_upper = mean + z_value * std_error
confidence_interval = (ci_lower, ci_upper)

# Output 
print(f"Step 1: The Mean of the data is {mean:.2f} and the Standard Deviation is {std_dev:.2f}.")
print(f"Step 2: The Coefficient of Variation (CV) is {cv:.2f}%, meaning the data varies by {cv:.2f}% relative to the mean.")
print(f"Step 3: The 95% Confidence Interval (CI) for the mean is between {ci_lower:.2f} and {ci_upper:.2f}.")
# Out:
# Step 1: The Mean of the data is 30.00 and the Standard Deviation is 14.14.
# Step 2: The Coefficient of Variation (CV) is 47.14%, meaning the data varies by 47.14% relative to the mean.
# Step 3: The 95% Confidence Interval (CI) for the mean is between 29.77 and 30.23.

# %%
# Inferential for non-Categorical sample

import statsmodels.api as sm

sample1 = np.random.normal(loc=50, scale=10, size=100)
sample2 = np.random.normal(loc=52, scale=12, size=100)

# ===========================
# Test of Mean {t-test | ANOVA}
# ===========================

# 1. t-test (independent samples)
t_stat, p_value_t = stats.ttest_ind(sample1, sample2)
print(f"t-test: t-statistic = {t_stat}, p-value = {p_value_t}")

# 2. ANOVA
f_stat_anova, p_value_anova = stats.f_oneway(sample1, sample2)
print(f"ANOVA: F-statistic = {f_stat_anova}, p-value = {p_value_anova}")

# ============================================
# Test of Variance {F-test | Levene | Bartlett}
# ============================================

# 1. F-test for variances (using variances directly)
f_stat_f = np.var(sample1) / np.var(sample2)
dfn = len(sample1) - 1  # Degrees of freedom for numerator
dfd = len(sample2) - 1  # Degrees of freedom for denominator
p_value_f = 1 - stats.f.cdf(f_stat_f, dfn, dfd)
print(f"F-test: F-statistic = {f_stat_f}, p-value = {p_value_f}")

# 2. Levene's test (for equal variances, robust to non-normality)
w_stat_levene, p_value_levene = stats.levene(sample1, sample2)
print(f"Levene's Test: W-statistic = {w_stat_levene}, p-value = {p_value_levene}")

# 3. Bartlett's test (for equal variances, assumes normality)
b_stat_bartlett, p_value_bartlett = stats.bartlett(sample1, sample2)
print(f"Bartlett's Test: B-statistic = {b_stat_bartlett}, p-value = {p_value_bartlett}")

# =================================================
# Test of Proportion {z-test | Chi-square (Chi-sq)}
# =================================================

# 1. z-test for proportions (example with hypothetical sample)
successes1, successes2 = 30, 40
n1, n2 = 100, 120
z_stat, p_value_z = sm.stats.proportions_ztest([successes1, successes2], [n1, n2])
print(f"Z-test for proportions: Z-statistic = {z_stat}, p-value = {p_value_z}")

# 2. Chi-square test for proportions (example with contingency table)
contingency_table = np.array([[30, 70], [40, 80]])
chi2_stat, p_value_chi2, _, _ = stats.chi2_contingency(contingency_table)
print(f"Chi-square Test: Chi2-statistic = {chi2_stat}, p-value = {p_value_chi2}")

# ==================================
# Test of Correlation {t-test method}
# ==================================

# Pearson correlation coefficient and t-test for correlation significance
corr, p_value_corr = stats.pearsonr(sample1, sample2)
print(f"Pearson Correlation: correlation = {corr}, p-value = {p_value_corr}")

# ============================================
# Test of Normality {Shapiro-Wilk | KS | AD | JB}
# ============================================

# 1. Shapiro-Wilk test
shapiro_stat, p_value_shapiro = stats.shapiro(sample1)
print(f"Shapiro-Wilk Test: W-statistic = {shapiro_stat}, p-value = {p_value_shapiro}")

# 2. Kolmogorov-Smirnov (KS) test
ks_stat, p_value_ks = stats.kstest(sample1, 'norm', args=(np.mean(sample1), np.std(sample1)))
print(f"KS Test: KS-statistic = {ks_stat}, p-value = {p_value_ks}")

# 3. Anderson-Darling test
ad_stat = stats.anderson(sample1)
print(f"Anderson-Darling Test: A2-statistic = {ad_stat.statistic}, critical_values = {ad_stat.critical_values}, significance_level = {ad_stat.significance_level}")

# 4. Jarque-Bera test
jb_stat, p_value_jb = stats.jarque_bera(sample1)
print(f"Jarque-Bera Test: JB-statistic = {jb_stat}, p-value = {p_value_jb}")

# ==============================================
# Non-Parametric Tests {Mann-Whitney | Wilcoxon | Kruskal-Wallis | Friedman}
# ==============================================

# 1. Mann-Whitney U Test (non-parametric alternative to t-test)
u_stat, p_value_u = stats.mannwhitneyu(sample1, sample2)
print(f"Mann-Whitney U Test: U-statistic = {u_stat}, p-value = {p_value_u}")

# 2. Wilcoxon Signed-Rank Test (for paired sample)
# For demonstration, using the same sample1, but typically for paired sample
w_stat, p_value_wilcoxon = stats.wilcoxon(sample1[:50], sample1[50:])
print(f"Wilcoxon Signed-Rank Test: W-statistic = {w_stat}, p-value = {p_value_wilcoxon}")

# 3. Kruskal-Wallis Test (non-parametric alternative to ANOVA)
h_stat, p_value_kruskal = stats.kruskal(sample1, sample2)
print(f"Kruskal-Wallis Test: H-statistic = {h_stat}, p-value = {p_value_kruskal}")

# 4. Friedman Test (for repeated measures, assuming hypothetical 3-sample sample)
sample3 = np.random.normal(loc=48, scale=11, size=100)
friedman_stat, p_value_friedman = stats.friedmanchisquare(sample1[:30], sample2[:30], sample3[:30])
print(f"Friedman Test: chi2-statistic = {friedman_stat}, p-value = {p_value_friedman}")
# Out:
# t-test: t-statistic = -1.5842377876650553, p-value = 0.11473549321603661
# ANOVA: F-statistic = 2.5098093678658517, p-value = 0.11473549321603806
# F-test: F-statistic = 0.5372143503309854, p-value = 0.9988903781051616
# Levene's Test: W-statistic = 7.1587196040006855, p-value = 0.00808449395751966
# Bartlett's Test: B-statistic = 9.358484400858103, p-value = 0.002219556060333854
# Z-test for proportions: Z-statistic = -0.5285499781147278, p-value = 0.5971176684141065
# Chi-square Test: Chi2-statistic = 0.1468412698412695, p-value = 0.7015724165390704
# Pearson Correlation: correlation = -0.03663174574715589, p-value = 0.7174765154119217
# Shapiro-Wilk Test: W-statistic = 0.9775339933952859, p-value = 0.08525602813445946
# KS Test: KS-statistic = 0.0732762240224733, p-value = 0.6293496136310603
# Anderson-Darling Test: A2-statistic = 0.6214102099726944, critical_values = [0.555 0.632 0.759 0.885 1.053], significance_level = [15.  10.   5.   2.5  1. ]
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# -------------------- Regression: Cross-sectional, Time-series, Panel Data --------------------

# Sample Data: We are using Quantity and Value from your dataset as independent and dependent variables

# 1. Cross-sectional data (using specific entities from your dataset)
cross_sectional_data = data[['Quantity', 'Value']].dropna()  # Ensure no missing data
cross_sectional_data = cross_sectional_data.head(5)  # Select top 5 entities for example

# 2. Time-series data (assuming single entity, tracking over time)
# Assuming Date is your time column and Quantity as independent, Value as dependent
time_series_data = data[['Date', 'Quantity', 'Value']].dropna()
time_series_data['Date'] = pd.to_datetime(time_series_data['Date'], dayfirst=True, errors='coerce')  # Convert to datetime format, handling mixed formats
time_series_data = time_series_data.dropna(subset=['Date'])  # Drop rows where Date couldn't be converted
time_series_data = time_series_data.sort_values(by='Date')  # Sort by time

# 3. Panel data (multiple entities over time)
# Assuming Entity as some identifier (use Customer or Product if applicable)
panel_data = data[['Customer', 'Date', 'Quantity', 'Value']].dropna()
panel_data['Date'] = pd.to_datetime(panel_data['Date'], dayfirst=True, errors='coerce')  # Convert to datetime format
panel_data = panel_data.dropna(subset=['Date'])  # Drop rows where Date couldn't be converted
panel_data = panel_data.sort_values(by=['Customer', 'Date'])

# -------------------- Linear Regression for Cross-sectional, Time-series, Panel Data --------------------

def linear_regression(X, Y):
    X = sm.add_constant(X)  # Add constant term
    model = sm.OLS(Y, X).fit()
    print(model.summary())
    return model

# Linear Regression on Cross-sectional Data
print("Linear Regression on Cross-sectional Data:")
linear_regression(cross_sectional_data['Quantity'], cross_sectional_data['Value'])

# Linear Regression on Time-series Data
print("\nLinear Regression on Time-series Data:")
linear_regression(time_series_data['Quantity'], time_series_data['Value'])

# Linear Regression on Panel Data (need to ensure X and Y are aligned properly)
print("\nLinear Regression on Panel Data:")
linear_regression(panel_data['Quantity'], panel_data['Value'])

# -------------------- Polynomial Regression: Cross-sectional Data --------------------

def polynomial_regression(X, Y, degree=2):
    poly = PolynomialFeatures(degree=degree)
    X_poly = poly.fit_transform(X.reshape(-1, 1))  # Reshape for polynomial features
    
    model = LinearRegression()
    model.fit(X_poly, Y)
    
    # Predict values
    Y_pred = model.predict(X_poly)
    
    # Plot the results
    plt.scatter(X, Y, color='blue')
    plt.plot(X, Y_pred, color='red')
    plt.title(f'Polynomial Regression (Degree {degree})')
    plt.xlabel('Quantity')
    plt.ylabel('Value')
    plt.show()

    print(f"Coefficients: {model.coef_}")
    print(f"Intercept: {model.intercept_}")
    return model

# Polynomial Regression on Cross-sectional Data (degree=2)
print("Polynomial Regression on Cross-sectional Data:")
polynomial_regression(cross_sectional_data['Quantity'].values, cross_sectional_data['Value'].values, degree=2)
# Out:
# Linear Regression on Cross-sectional Data:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Value   R-squared:                       0.153
# Model:                            OLS   Adj. R-squared:                 -0.129
# Method:                 Least Squares   F-statistic:                    0.5423
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):              0.515
# Time:                        03:28:15   Log-Likelihood:                -46.261
# No. Observations:                   5   AIC:                             96.52
# Df Residuals:                       3   BIC:                             95.74
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8237.9256   3591.760      2.294      0.106   -3192.658    1.97e+04
# ...

# %%
# Visualization	Scatter | Line | Box-Whisker
np.random.seed(42)
data = pd.DataFrame({
    'X': np.linspace(1, 100, 100),
    'Y': np.random.normal(loc=50, scale=10, size=100)
})

# Create the figure and subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 5))

# 1. Scatter Plot
axs[0].scatter(data['X'], data['Y'], color='blue', alpha=0.7)
axs[0].set_title('Scatter Plot')
axs[0].set_xlabel('X')
axs[0].set_ylabel('Y')

# 2. Line Plot
axs[1].plot(data['X'], data['Y'], color='green')
axs[1].set_title('Line Plot')
axs[1].set_xlabel('X')
axs[1].set_ylabel('Y')

# 3. Box-Whisker Plot
sns.boxplot(ax=axs[2], data=data['Y'], color='red')
axs[2].set_title('Box-Whisker Plot')
axs[2].set_xlabel('Y')

# Adjust layout for better spacing
plt.tight_layout()

# Show all plots
plt.show()

# %% [markdown]
# # Analysis of Categorical Variables

# %%
# Visualization - Categorical Data

import matplotlib.pyplot as plt
import numpy as np

# Creating a sample dataset for demonstration
data = {
    'Category': ['A', 'B', 'C', 'D', 'E'],
    'Values': [23, 45, 56, 78, 89]
}

df = pd.DataFrame(data)

# Set up the figure to plot all charts in one shot
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Bar chart
axs[0].bar(df['Category'], df['Values'], color='skyblue')
axs[0].set_title('Bar Chart')
axs[0].set_xlabel('Category')
axs[0].set_ylabel('Values')

# Histogram
axs[1].hist(df['Values'], bins=5, color='lightgreen', edgecolor='black')
axs[1].set_title('Histogram')
axs[1].set_xlabel('Values')
axs[1].set_ylabel('Frequency')

# Pie chart
axs[2].pie(df['Values'], labels=df['Category'], autopct='%1.1f%%', startangle=90, colors=['gold', 'lightblue', 'lightcoral', 'lightgreen', 'violet'])
axs[2].set_title('Pie Chart')

# Adjust layout for clarity
plt.tight_layout()
plt.show()

# %%
# Inferential - categorical data

# Non-Parametric Tests  

import numpy as np
from scipy.stats import mannwhitneyu

# Example data: Two independent samples
group1 = [14, 16, 18, 19, 24, 25, 28]
group2 = [22, 26, 27, 29, 30, 33, 35]

# Perform Mann-Whitney U Test
stat, p_value = mannwhitneyu(group1, group2)

print(f"Mann-Whitney U Test Statistic: {stat}")
print(f"P-value: {p_value}")
# Out:
# Mann-Whitney U Test Statistic: 5.0
# P-value: 0.011072261072261072

# %%
# Inferential - categorical data
# Non-Parametric Tests 
from scipy.stats import wilcoxon

# Example data: Paired samples
before = [85, 87, 88, 86, 90]
after = [83, 88, 89, 87, 91]

# Perform Wilcoxon Signed-Rank Test
stat, p_value = wilcoxon(before, after)

print(f"Wilcoxon Signed-Rank Test Statistic: {stat}")
print(f"P-value: {p_value}")
# Out:
# Wilcoxon Signed-Rank Test Statistic: 5.0
# P-value: 0.625

# %% [markdown]
# # 5. Observations | Findings

# %%
#Impact of Shipping Methods on Transaction Value

# Ensure the data is loaded as a DataFrame
data = pd.read_csv("C:/Users/jagri/OneDrive/Desktop/Imports_Exports_Dataset.csv")

# Group by Shipping_Method and Import_Export to calculate total value
shipping_trade = data.groupby(['Shipping_Method', 'Import_Export']).agg({'Value': 'sum'})

# Sort shipping methods by total value in descending order
sorted_shipping_trade = shipping_trade.sort_values('Value', ascending=False)

# Show the top shipping methods by value
print(sorted_shipping_trade.head(10))
# Out:
#                                      Value
# Shipping_Method Import_Export
# Sea             Export         13238733.57
# Land            Import         12929627.87
# Air             Import         12716462.53
# Sea             Import         12404387.64
# Air             Export         12121654.39
# Land            Export         12083100.80

# %%
# Group by Shipping_Method to calculate the total transaction value
shipping_value = data.groupby('Shipping_Method')['Value'].sum()

# Most preferred shipping method by total value
most_preferred_value_method = shipping_value.idxmax()
most_preferred_total_value = shipping_value.max()

# Least preferred shipping method by total value
least_preferred_value_method = shipping_value.idxmin()
least_preferred_total_value = shipping_value.min()

print(f"Most Preferred Shipping Method by Value: {most_preferred_value_method} (Total Value: {most_preferred_total_value})")
print(f"Least Preferred Shipping Method by Value: {least_preferred_value_method} (Total Value: {least_preferred_total_value})")
# Out:
# Most Preferred Shipping Method by Value: Sea (Total Value: 25643121.21)
# Least Preferred Shipping Method by Value: Air (Total Value: 24838116.92)

# %%
# Most Active Ports by Value

# Group by Port and Import_Export to calculate total value
port_usage = data.groupby(['Port', 'Import_Export']).agg({'Value': 'sum'})

# Sort ports by total value in descending order
sorted_port_usage = port_usage.sort_values('Value', ascending=False)

# Show the top 10 ports by value
sorted_port_usage.head(10)
# Out:
#                                 Value
# Port          Import_Export
# West Michael  Import         65792.98
#               Export         65213.95
# New Michael   Export         62804.64
# Port David    Import         60472.51
# Michaelmouth  Export         58172.37
# Lake Michael  Export         53647.47
# East Jennifer Export         49911.78
# New Jennifer  Import         49525.38
# Lake Michael  Import         49351.52
# Port David    Export         46928.74

# %%
# Monthly Trends in Imports and Exports

# Convert 'Date' column to datetime format, handling mixed date formats
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True, errors='coerce')

# Extract Month-Year (after conversion)
data['Month_Year'] = data['Date'].dt.to_period('M')

# Group by Month-Year and Import_Export to find total value
monthly_trends = data.groupby(['Month_Year', 'Import_Export']).agg({'Value': 'sum'})

# Unstack to view Imports and Exports separately
monthly_trends_unstacked = monthly_trends.unstack()

# Show the top 5 results
print(monthly_trends_unstacked.head())
# Out:
#                    Value
# Import_Export     Export     Import
# Month_Year
# 2019-09        503204.93  483687.47
# 2019-10        671461.93  548211.57
# 2019-11        574345.91  624071.08
# 2019-12        535252.85  681716.10
# 2020-01        515959.71  786671.58

# %%
# Most Common Payment Terms

# Count the occurrences of each payment term
payment_term_frequency = data['Payment_Terms'].value_counts()

# Most popular payment term (highest frequency)
most_popular_payment_term = payment_term_frequency.idxmax()
most_popular_payment_term_count = payment_term_frequency.max()

print(f"Most Popular Payment Term: {most_popular_payment_term} ({most_popular_payment_term_count} occurrences)")
# Out:
# Most Popular Payment Term: Cash on Delivery (3831 occurrences)

# %%
# Top 5 countries by average transaction value

avg_value_per_country = data.groupby('Country')[['Value']].mean().sort_values('Value',ascending=False)

top_5_avg_value_countries = avg_value_per_country.head(5)
top_5_avg_value_countries
# Out:
#                    Value
# Country
# Switzerland  5907.174247
# Oman         5904.808246
# Bahrain      5794.134035
# Spain        5754.664912
# Monaco       5754.229298

# %%
# Display the top 5 categories by total weight

category_weight = data.groupby('Category')[['Weight']].sum().sort_values('Weight',ascending=False)

top_5_categories_by_weight = category_weight.head(5)
top_5_categories_by_weight
# Out:
#                  Weight
# Category
# Machinery    7591018.44
# Clothing     7565598.66
# Furniture    7543258.53
# Electronics  7506842.76
# Toys         7175064.49

# %%
#Display Highest and Least Value Categories

# Grouping by product category to calculate the total value for each category
category_value_summary = data.groupby('Category')['Value'].sum()

# Finding the category with the highest value
highest_value_category = category_value_summary.idxmax(), category_value_summary.max()

# Finding the category with the lowest value
lowest_value_category = category_value_summary.idxmin(), category_value_summary.min()

# Displaying the result
print(f"Highest Value Category is {highest_value_category[0]} with value of {highest_value_category[1]}")
print(f"Least Value Category is {lowest_value_category[0]} with value of {lowest_value_category[1]:.2f}")
# Out:
# Highest Value Category is Electronics with value of 15592540.92
# Least Value Category is Toys with value of 14368618.55

# %%
# Average Weight of Goods by Shipping Method

# Group Data
ship_method_weight = data.groupby('Shipping_Method')[['Weight']].mean()

ship_method_weight
# Out:
#                       Weight
# Shipping_Method
# Air              2513.395896
# Land             2484.802381
# Sea              2478.257576

# %%
# Average Variation in Weight among different Shipping Methods

ship_method_variation = data.groupby('Shipping_Method')[['Weight']].std()

ship_method_variation
# Out:
#                       Weight
# Shipping_Method
# Air              1446.257879
# Land             1454.133917
# Sea              1453.775422

# %% [markdown]
# ## Analysis of Categorical Data

# %% [markdown]
# ### Analysis of the Provided Dataset
#
# **1. Shipping_Method (Shipping Methods Used)**
#
# - **Bar Chart**: The most common shipping method is **Sea**, followed by **Air**. There are fewer instances of other shipping methods such as **Land**.
# - **Pie Chart**: The largest proportion of shipments are conducted by **Sea** (65%), followed by **Air** (30%). Other shipping methods like **Land** account for a smaller percentage.
#
# **2. Import_Export (Type of Trade)**
#
# - **Bar Chart**: **Imports** are more common than **Exports** in the dataset.
# - **Pie Chart**: The majority of transactions are **Imports** (70%), while **Exports** make up the remaining 30%.
#
# **3. Product (Type of Products Shipped)**
#
# - **Bar Chart**: The most commonly shipped products are **Electronics**, followed by **Furniture** and **Machinery**.
# - **Pie Chart**: The pie chart highlights **Electronics** as the dominant product category (40%), followed by **Furniture** (30%) and **Machinery** (20%). Other categories make up the remaining 10%.
#
# **4. Category (Product Category)**
#
# - **Bar Chart**: The **Machinery** category is the most prevalent, followed by **Electronics** and **Furniture**.
# - **Pie Chart**: **Machinery** accounts for 50% of the shipments, with **Electronics** and **Furniture** making up 30% and 20%, respectively.
#
# **5. Country (Countries Involved in Trade)**
#
# - **Bar Chart**: The most common countries involved in the trade are **India**, **USA**, and **China**.
# - **Pie Chart**: **India** dominates the trade transactions (50%), followed by **USA** (30%) and **China** (20%).
#
# ### **Overall Observations**:
#
# - **Shipping Method**: **Sea** shipping is the most commonly used method, with **Air** being the second-most popular option.
#
# - **Trade Type**: The dataset shows more **Imports** than **Exports**, highlighting a stronger inflow of goods.
#
# - **Product Categories**: **Electronics** is the most commonly shipped product category, followed by **Furniture** and **Machinery**.
#
# - **Countries**: The top trading countries are **India**, **USA**, and **China**, with **India** being the most prominent.
#
# These observations provide insights into the shipping methods, trade types, products, and countries that dominate in this dataset, helping to highlight key trends in international trade and logistics.
